# %%
import sys
sys.path.append('..')
import torch
import torch.nn as nn
import torch.optim as optim
from modules.models import *
from rpn._rpn_fpn import _RPN_FPN
from rpn._proposal_target_layer import _ProposalTargetLayer
import torchvision
from torchvision import models
import numpy as np
from torchvision import transforms
from torchvision.transforms import Compose
import utils.transform as transf
from torch.utils.data import DataLoader
from utils.utils import bbox_collate, data2target,MixedRandomSampler
from rpn._bbox_transform import bbox_transform_inv, clip_boxes, clip_boxes_batch
from rpn.config import cfg
import yaml
import os
import json
import copy
from PIL import Image
from dataset.dataset import MedicalBboxDataset
from dataset.make_dloader import make_data
import time
import collections
from utils.anchor import make_anchor
from torchvision.ops import nms
from rpn.net_utils import _smooth_l1_loss

import matplotlib.pyplot as plt

# %%
config = yaml.safe_load(open('../config.yaml'))
dataset_means = json.load(open(config['dataset']['mean_file']))
unnormalize = transf.UnNormalize(dataset_means['mean'], dataset_means['std'])

# %%
dl_t, _, dl_v, dataset_val, _ = make_data(batchsize=4,iteration=100,val=1,p_path=0)

# %%
model = faster_rcnn(3,pretrained=False)
model.load_state_dict(torch.load("/data/unagi0/masaoka/wsod/model/oicr/F-RCNNfaster0.0005_0_1.pt"))
model.cuda()
#model.eval()
opt = optim.RMSprop(model.parameters(), lr = 1e-5, weight_decay=5e-4, momentum=0.9)

# %%
p_box = make_anchor()

# %%
for i, data in enumerate(dl_v,1):
    opt.zero_grad()
    labels, n, t, v, u= data2target(data)
    labels = labels.unsqueeze(1).unsqueeze(2).cuda().float() # bs, 1, 1, num_class
    rois = [p_box.cuda().float() for _ in range(labels.shape[0])]
    n = p_box.shape[0]
    rois = torch.stack(rois, dim=0) 
    rois = rois.unsqueeze(1) #bs, 1, n, 4
    rois = model(data["img"].cuda().float(), labels, rois,n)
    rois = rois[0]
    break
# Out:
# tensor([[0.9339, 0.0664, 0.0015, 0.0043]], device='cuda:0',
#        grad_fn=<SumBackward1>)

# %%
for i in range(len(rois)):
    mat = np.zeros((256,256))
    x1 = int(rois[i][0])//2
    y1 = int(rois[i][1])//2
    x2 = int(rois[i][2])//2
    y2 = int(rois[i][3])//2
    mat[y1:y2,x1:x2] = 1
    plt.imshow(mat)
    plt.show()

# %%
model.eval()
x=0
for i, data in enumerate(dl_v,1):
    print(f'{i}/{len(dl_v)}',end='\r')
    for i in range(len(data["bboxes"][0])):
        label_name = dataset_val.labels[int(data["labels"][0][i])]
    if label_name != 'torose lesion':
        continue
    opt.zero_grad()
    labels, n, t, v, u= data2target(data)
    labels = labels.unsqueeze(1).unsqueeze(2).cuda().float() # bs, 1, 1, num_class
    rois = [p_box.cuda().float() for _ in range(labels.shape[0])]
    n = p_box.shape[0]
    rois = torch.stack(rois, dim=0) 
    rois = rois.unsqueeze(1) #bs, 1, n, 4
    #output, loss,m,l1,l2,l3,retina,rpn = model(data["img"].cuda().float(), labels, rois,n)
    scores, classification, transformed_anchors = model(data["img"].cuda().float(), labels, rois,n)
    idxs = np.where(scores.cpu()>0.1)
    
    data['img'] = data['img'].squeeze(dim=0)
        
    print(scores)
    print(classification)
    print(transformed_anchors)
    img = unnormalize(data)['img'].copy() 
    img[img<0] = 0
    img[img>255] = 255
    for j in range(idxs[0].shape[0]):
        if int(classification[idxs[0][j]]) == 3:
            continue
        bbox = transformed_anchors[idxs[0][j], :]
        
        x1 = int(bbox[0])
        y1 = int(bbox[1])
        x2 = int(bbox[2])
        y2 = int(bbox[3])
        label_name_ = dataset_val.labels[int(classification[idxs[0][j]])]
        #draw_caption(img, (x1, y1, x2, y2), label_name_)
        if label_name_ == "ulcer":
            cv2.rectangle(img, (x1, y1), (x2, y2), color=(255, 255,0), thickness=2) #黄色
        elif label_name_ == "torose lesion":
            cv2.rectangle(img, (x1, y1), (x2, y2), color=(0, 0,255), thickness=2) #青
        else:
            cv2.rectangle(img, (x1, y1), (x2, y2), color=(255, 0,0), thickness=2) #赤
                
    mat = np.zeros((512,512))
    for i in range(len(data["bboxes"][0])):
        x1 = int(data["bboxes"][0][i][0])
        y1 = int(data["bboxes"][0][i][1])
        x2 = int(data["bboxes"][0][i][2])
        y2 = int(data["bboxes"][0][i][3])
        mat[y1:y2,x1:x2] = 1
        plt.imshow(mat)
        plt.show()
        label_name = dataset_val.labels[int(data["labels"][0][i])]
        #draw_caption(img, (x1, y1, x2, y2), label_name)
        if label_name == "ulcer":
            cv2.rectangle(img, (x1, y1), (x2, y2), color=(255, 255, 255), thickness=2) #黄色
        elif label_name == "torose lesion":
            cv2.rectangle(img, (x1, y1), (x2, y2), color=(255, 255, 255), thickness=2) #青
        else:
            cv2.rectangle(img, (x1, y1), (x2, y2), color=(255, 255, 255), thickness=2)  #赤
        print(label_name)
    plt.axis("off")
    plt.imshow(img)
    plt.show()
    
    x+=1
    if x == 50:
        break
# Out:
# tensor([[0.9339, 0.0664, 0.0015, 0.0043]], device='cuda:0',
#        grad_fn=<SumBackward1>)
# tensor([])
# tensor([])
# tensor([])
# torose lesion
# tensor([[8.5841e-01, 7.2856e-02, 2.8888e-04, 5.1750e-04]], device='cuda:0',
#        grad_fn=<SumBackward1>)
# tensor([])
# tensor([])
# tensor([])
# torose lesion
# tensor([[9.9887e-01, 3.3865e-04, 5.9156e-04, 2.1672e-03]], device='cuda:0',
#        grad_fn=<SumBackward1>)
# tensor([])
# tensor([])
# tensor([])
# torose lesion
# tensor([[0.9663, 0.0160, 0.0015, 0.0200]], device='cuda:0',
#        grad_fn=<SumBackward1>)
# tensor([])
# tensor([])
# tensor([])
# torose lesion
# tensor([[0.9361, 0.0073, 0.0017, 0.0176]], device='cuda:0',
#        grad_fn=<SumBackward1>)
# tensor([])
# tensor([])
# tensor([])
# torose lesion
# tensor([[0.9664, 0.0243, 0.0015, 0.0019]], device='cuda:0',
#        grad_fn=<SumBackward1>)
# tensor([])
# tensor([])
# tensor([])
# torose lesion
# ...
